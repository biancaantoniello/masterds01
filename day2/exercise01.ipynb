# %%
if 10 >5 :
    print("10 is bigger than 5")
# Out:
# 10 is bigger than 5

# %%
def sum(a,b):
    """
    this function receives two values that are summed toghether 
    """
    result = a+b # a is added to b and associated with 'result'
    return result #we return the 'result' variable

# %%
sum(10,20)
sum("Mike","Elisa") # posso concatenare due stringhe
#sum("Mike",5) # non funziona
# Out:
# 'MikeElisa'

# %%
building1_name = "Church" # snake syntax
building1Name = "Stadium" # camel syntax

# %%
print(building1_name)
# Out:
# Church

# %%
student_name = "Maria"

# %%
type(student_name)
# Out:
# str

# %%
dangerous = True

# %%
type(dangerous)
# Out:
# bool

# %%
d = str(dangerous)
type(d)
# Out:
# str

# %%
d
# Out:
# 'True'

# %%
s = "20"

# %%
int(s)+int(s)
# Out:
# 40

# %%
s+s
# Out:
# '2020'

# %%
a = 10
b = "Julie"
c = True
d = 3.5

# %%
type(d)
# Out:
# float

# %%
float(a)
# Out:
# 10.0

# %%
type(float(a))
# Out:
# float
