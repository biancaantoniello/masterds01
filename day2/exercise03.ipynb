# %%
s1 = 'ciao'
s2 = "come stai?"
s3 = """bene grazie
tu?
"""

# %%
nome = "Bianca"

# %%
print(f"ciao {nome}")
# Out:
# ciao Bianca

# %%
s4 = s2[:2]
s5 = s2[-2:]
res1 = s4+s5
print(res1)
# Out:
# coi?

# %%
s = "Bene grazie"
res2 = s[:2].lower()+s[2:9]+s[-2:].upper()
res2
# Out:
# 'bene grazIE'
